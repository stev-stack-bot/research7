# %% [markdown]
# # Lighter DEX OBI Scalper Research Notebook
#
# This notebook demonstrates the Lighter OBI Scalper pipeline run, featuring:
# 1. Volume bar construction from trades
# 2. Book update mapping using microsecond timestamps
# 3. OFI feature computation
# 4. Standard vs Premium execution backtesting
# 5. Leakage checks

# %%
import sys
import os
sys.path.append('..')
from src.run_lighter_pipeline import run_lighter_pipeline

run_lighter_pipeline()
